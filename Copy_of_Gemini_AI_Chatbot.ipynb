# %%
# !pip install -q -U google-generativeai

import google.generativeai as genai
from getpass import getpass

api_key = getpass("enter your key")

genai.configure(api_key=api_key)

model = genai.GenerativeModel("models/gemini-flash-lite-latest")

print("Chatbot Started!")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        break

    try:
        response = model.generate_content(user)
        print("Bot:", response.text)

    except Exception as e:
        print("Error:", e)
# Out:
# enter your key··········
# Chatbot Started!
# You: hi
# Bot: Hello! How can I help you today?
# You: can you help me create the job resume
# Bot: I would be happy to help you build a professional resume! To get started, we can take one of two approaches:
#
# ### Option 1: You provide the info, I write the draft
# Copy and paste the following details (or just fill in what you have), and I will format it into a professional layout for you:
#
# 1.  **Contact Info:** (Name, City/State, Phone, Email, LinkedIn URL)
# 2.  **Professional Summary:** (A 2–3 sentence "elevator pitch" about who you are and what you bring to the table).
# 3.  **Work History:** (Job titles, company names, dates of employment, and 3–4 bullet points of your key accomplishments for each).
# 4.  **Skills:** (Software, languages, technical skills, or soft skills like leadership).
# 5.  **Education:** (Degrees, certifications, or relevant coursework).
#
# ---
#
# ### Option 2: I provide a template, and you fill it in
# If you aren't ready to share your details yet, here is a standard, recruiter-friendly structure you can use:
#
# **[FULL NAME]**
# [City, State] | [Phone Number] | [Email Address] | [LinkedIn Profile Link]
#
# **PROFESSIONAL SUMMARY**
# *Dynamic and results-oriented [Job Title] with [Number] years of experience in [Industry]. Proven track record of [mention a key achievement, e.g., increasing sales by 20% or streamlining office processes].*
#
# **CORE SKILLS**
# *   **Technical:** [Skill 1], [Skill 2], [Skill 3]
# *   **Soft Skills:** [Leadership], [Communication], [Problem Solving]
#
# **PROFESSIONAL EXPERIENCE**
# **[Job Title]** | [Company Name] | [Dates of Employment]
# *   [Action Verb] + [Task] + [Result/Metric]. (Example: *Managed a team of 5 to increase project output by 15% within six months.*)
# *   [Action Verb] + [Task] + [Result/Metric].
#
# **EDUCATION**
# **[Degree Name]** | [University Name] | [Year Graduated]
#
# ---
#
# ### 3 Tips for a Winning Resume:
# 1.  **Use Action Verbs:** Start every bullet point with words like *Spearheaded, Developed, Managed, Created,* or *Analyzed.*
# 2.  **Quantify Whenever Possible:** Recruiters love numbers. Instead of saying "I helped with sales," say "I contributed to a 10% increase in quarterly sales."
# 3.  **Tailor it:** If you have a specific job description in mind, paste it here! I can help you "keyword optimize" your resume so it gets past the automated screening software (ATS) that companies use.
#
# **Which would you like to do? If you have your rough notes ready, paste them below and I will polish them into a professional format!**
# You: exit
